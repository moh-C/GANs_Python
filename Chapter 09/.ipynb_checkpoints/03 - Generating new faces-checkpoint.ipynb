# %% [markdown]
# # Importing the libraries

# %%
import numpy as np
import keras
import matplotlib.pyplot as plt
# Out:
# Using TensorFlow backend.

# %% [markdown]
# # Generating latent points and fake examples

# %%
def generate_latent_points(latent_dim, n_samples):
    x_input = np.random.randn(latent_dim * n_samples)
    x_input = x_input.reshape((n_samples, latent_dim))
    return x_input

# %%
def generate_fake_samples(generator, latent_dim, n_samples):
    x_input = generate_latent_points(latent_dim= latent_dim,
                                     n_samples= n_samples)
    X = generator.predict(x_input)
    y = np.zeros((n_samples, 1))
    return X, y

# %% [markdown]
# # Using the trained model

# %%
latent_dim = 200
n_samples = 25
model = keras.models.load_model('./generator_model_135.h5', compile= False)
X, _ = generate_fake_samples(generator= model,
                             latent_dim= latent_dim,
                             n_samples= n_samples)
save_plot(x_input= X, n= int(np.sqrt(n_samples)))

# %%
def plotter(model, n_samples=49):
    plt.figure(figsize=(18,9))
    for i in range(n_samples):
        ran = np.random.randn(n_samples, 200)
        sqrt = int(np.sqrt(n_samples))
        plt.subplot(sqrt, sqrt, i+1)
        X = model.predict(ran)
        X = (X + 1) / 2.0
        plt.imshow(X[0])
        plt.axis('off')
    plt.show()

# %% [markdown]
# # Predicting the faces

# %%
pnts = plotter(model, n_samples= 25)
