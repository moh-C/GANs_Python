# %% [markdown]
# # Importing the libraries

# %%
import keras
import numpy as np
import matplotlib.pyplot as plt
# Out:
# Using TensorFlow backend.

# %% [markdown]
# # Plotter

# %%
def plot_faces(model, latent_dim, n=4):
    x_input = generate_latent_points(latent_dim, n * n)
    X = model.predict(x_input)
    X = (X + 1) / 2
    for i in range(n * n):
        plt.subplot(n, n, i+1)
        plt.imshow(X[i])
        plt.axis('off')
    plt.show()

# %% [markdown]
# # Generating the latent points

# %%
def generate_latent_points(latent_dim, n_samples):
    x_input = np.random.randn(latent_dim * n_samples)
    x_input = x_input.reshape((n_samples, latent_dim))
    return x_input

# %% [markdown]
# # Loading the model

# %%
latent_dim = 200
model = keras.models.load_model('drive/My Drive/CGAN/LS_g_model_e_40.h5')
# Out:
# /usr/local/lib/python3.6/dist-packages/keras/engine/saving.py:341: UserWarning: No training configuration found in save file: the model was *not* compiled. Compile it manually.
#   warnings.warn('No training configuration found in save file: '

# %% [markdown]
# # Plotting the pics

# %%
plt.figure(figsize= (20, 10))
plot_faces(model, latent_dim, n= 3)
